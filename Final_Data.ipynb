# %%
#import packages
from pytrends.request import TrendReq
import csv
import time
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import numpy as np
from plotnine import *
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno # https://github.com/ResidentMario/missingno

# %%
#Connecting to Google (WORKS)
pytrends = TrendReq(hl='en-US', tz=360)

# %%
#Building Payload
kw_list = ["Economia", "Previdência", "Bolsa Família", "Desemprego", "Plano Governo"]
timeframes = ['2018-10-14 2018-10-28', '2018-9-23 2018-10-7', '2014-10-12 2014-10-26', '2014-9-21 2014-10-5', '2010-10-17 2010-10-31', '2010-9-19 2010-10-3', '2006-10-15 2006-10-29', '2006-9-17 2006-10-1']
#segmented for national and most populous states in each region
geos = ["BR","BR-AM", "BR-BA", "BR-MS", "BR-SP", "BR-RS"]

# %%
#definitions for columns
years = ["2018", "2014", "2010","2006",]
rounds = ["2","1"]
regions = ["BR","BR-AM", "BR-BA", "BR-MS", "BR-SP", "BR-RS"]

# %%
#Region 1 Compiled

#Pulling 2018 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[0],
geo=geos[0])

BR_2018_2 = pytrends.interest_over_time()
BR_2018_2 = BR_2018_2.drop('isPartial', 1)

election_year = [years[0]]*len(BR_2018_2.index)
election_round= [rounds[0]]*len(BR_2018_2.index)
region= [regions[0]]*len(BR_2018_2.index)

BR_2018_2['Election Year'] = election_year
BR_2018_2['Election Round'] = election_round
BR_2018_2['Region'] = region


final = BR_2018_2.groupby(['Election Year','Election Round','Region']).mean()


# Pulling 2018 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[1],
geo=geos[0])

BR_2018_1 = pytrends.interest_over_time()
BR_2018_1 = BR_2018_1.drop('isPartial', 1)

election_year = [years[0]]*len(BR_2018_1.index)
election_round= [rounds[1]]*len(BR_2018_1.index)
region= [regions[0]]*len(BR_2018_1.index)

BR_2018_1['Election Year'] = election_year
BR_2018_1['Election Round'] = election_round
BR_2018_1['Region'] = region

final_1 = BR_2018_1.groupby(['Election Year','Election Round','Region']).mean()

final = pd.concat([final,final_1],sort=False)


# Pulling 2014 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[2],
geo=geos[0])

BR_2014_2 = pytrends.interest_over_time()
BR_2014_2 = BR_2014_2.drop('isPartial', 1)

election_year = [years[1]]*len(BR_2014_2.index)
election_round= [rounds[0]]*len(BR_2014_2.index)
region= [regions[0]]*len(BR_2014_2.index)

BR_2014_2['Election Year'] = election_year
BR_2014_2['Election Round'] = election_round
BR_2014_2['Region'] = region

final_2 = BR_2014_2.groupby(['Election Year','Election Round','Region']).mean()

final = pd.concat([final,final_2],sort=False)


# Pulling 2014 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[3],
geo=geos[0])

BR_2014_1 = pytrends.interest_over_time()
BR_2014_1 = BR_2014_1.drop('isPartial', 1)

election_year = [years[1]]*len(BR_2014_1.index)
election_round= [rounds[1]]*len(BR_2014_1.index)
region= [regions[0]]*len(BR_2014_1.index)

BR_2014_1['Election Year'] = election_year
BR_2014_1['Election Round'] = election_round
BR_2014_1['Region'] = region

final_3 = BR_2014_1.groupby(['Election Year','Election Round','Region']).mean()

final = pd.concat([final,final_3],sort=False)


# Pulling 2010 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[4],
geo=geos[0])

BR_2010_2 = pytrends.interest_over_time()
BR_2010_2 = BR_2010_2.drop('isPartial', 1)

election_year = [years[2]]*len(BR_2010_2.index)
election_round= [rounds[0]]*len(BR_2010_2.index)
region= [regions[0]]*len(BR_2010_2.index)

BR_2010_2['Election Year'] = election_year
BR_2010_2['Election Round'] = election_round
BR_2010_2['Region'] = region

final_4 = BR_2010_2.groupby(['Election Year','Election Round','Region']).mean()

final = pd.concat([final,final_4],sort=False)


# Pulling 2010 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[5],
geo=geos[0])

BR_2010_1 = pytrends.interest_over_time()
BR_2010_1 = BR_2010_1.drop('isPartial', 1)

election_year = [years[2]]*len(BR_2010_1.index)
election_round= [rounds[1]]*len(BR_2010_1.index)
region= [regions[0]]*len(BR_2010_1.index)

BR_2010_1['Election Year'] = election_year
BR_2010_1['Election Round'] = election_round
BR_2010_1['Region'] = region

final_5 = BR_2010_1.groupby(['Election Year','Election Round','Region']).mean()

final = pd.concat([final,final_5],sort=False)


# Pulling 2006 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[6],
geo=geos[0])

BR_2006_2 = pytrends.interest_over_time()
BR_2006_2 = BR_2006_2.drop('isPartial', 1)

election_year = [years[3]]*len(BR_2006_2.index)
election_round= [rounds[0]]*len(BR_2006_2.index)
region= [regions[0]]*len(BR_2006_2.index)

BR_2006_2['Election Year'] = election_year
BR_2006_2['Election Round'] = election_round
BR_2006_2['Region'] = region

final_6 = BR_2006_2.groupby(['Election Year','Election Round','Region']).mean()

final = pd.concat([final,final_6],sort=False)


# Pulling 2006 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[7],
geo=geos[0])

BR_2006_1 = pytrends.interest_over_time()
BR_2006_1 = BR_2006_1.drop('isPartial', 1)

election_year = [years[3]]*len(BR_2006_1.index)
election_round= [rounds[1]]*len(BR_2006_1.index)
region= [regions[0]]*len(BR_2006_2.index)

BR_2006_1['Election Year'] = election_year
BR_2006_1['Election Round'] = election_round
BR_2006_1['Region'] = region

final_7 = BR_2006_1.groupby(['Election Year','Election Round','Region']).mean()

final = pd.concat([final,final_7],sort=False)
final
# Out:
#                                       Economia  Previdência  Bolsa Família  \
# Election Year Election Round Region
# 2018          2              BR      73.066667    12.466667      23.933333
#               1              BR      48.466667     8.600000      10.266667
# 2014          2              BR      71.066667    11.000000      12.733333
#               1              BR      66.133333    10.733333       6.466667
# 2010          2              BR      59.666667     7.800000       2.133333
#               1              BR      64.866667     5.066667       0.800000
# 2006          2              BR      55.200000     7.133333       0.800000
#               1              BR      56.000000    11.466667       1.600000
#
#                                      Desemprego  Plano Governo
# Election Year Election Round Region
# 2018          2              BR       52.933333      63.466667
#               1              BR       35.066667      45.733333
# ...

# %%
#Region 2 Compiled

#Pulling 2018 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[0],
geo=geos[1])

BR_AM_2018_2 = pytrends.interest_over_time()
BR_AM_2018_2 = BR_AM_2018_2.drop('isPartial', 1)

election_year = [years[0]]*len(BR_AM_2018_2.index)
election_round= [rounds[0]]*len(BR_AM_2018_2.index)
region= [regions[1]]*len(BR_AM_2018_2.index)

BR_AM_2018_2['Election Year'] = election_year
BR_AM_2018_2['Election Round'] = election_round
BR_AM_2018_2['Region'] = region


final_AM = BR_AM_2018_2.groupby(['Election Year','Election Round','Region']).mean()


# Pulling 2018 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[1],
geo=geos[1])

BR_AM_2018_1 = pytrends.interest_over_time()
BR_AM_2018_1 = BR_AM_2018_1.drop('isPartial', 1)

election_year = [years[0]]*len(BR_AM_2018_1.index)
election_round= [rounds[1]]*len(BR_AM_2018_1.index)
region= [regions[1]]*len(BR_AM_2018_1.index)

BR_AM_2018_1['Election Year'] = election_year
BR_AM_2018_1['Election Round'] = election_round
BR_AM_2018_1['Region'] = region

final_1_AM = BR_AM_2018_1.groupby(['Election Year','Election Round','Region']).mean()

final_AM = pd.concat([final_AM,final_1_AM],sort=False)


# Pulling 2014 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[2],
geo=geos[1])

BR_AM_2014_2 = pytrends.interest_over_time()
BR_AM_2014_2 = BR_AM_2014_2.drop('isPartial', 1)

election_year = [years[1]]*len(BR_AM_2014_2.index)
election_round= [rounds[0]]*len(BR_AM_2014_2.index)
region= [regions[1]]*len(BR_AM_2014_2.index)

BR_AM_2014_2['Election Year'] = election_year
BR_AM_2014_2['Election Round'] = election_round
BR_AM_2014_2['Region'] = region

final_2_AM = BR_AM_2014_2.groupby(['Election Year','Election Round','Region']).mean()

final_AM = pd.concat([final_AM,final_2_AM],sort=False)


# Pulling 2014 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[3],
geo=geos[1])

BR_AM_2014_1 = pytrends.interest_over_time()
BR_AM_2014_1 = BR_AM_2014_1.drop('isPartial', 1)

election_year = [years[1]]*len(BR_AM_2014_1.index)
election_round= [rounds[1]]*len(BR_AM_2014_1.index)
region= [regions[1]]*len(BR_AM_2014_1.index)

BR_AM_2014_1['Election Year'] = election_year
BR_AM_2014_1['Election Round'] = election_round
BR_AM_2014_1['Region'] = region

final_3_AM = BR_AM_2014_1.groupby(['Election Year','Election Round','Region']).mean()

final_AM = pd.concat([final_AM,final_3_AM],sort=False)


# Pulling 2010 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[4],
geo=geos[1])

BR_AM_2010_2 = pytrends.interest_over_time()
BR_AM_2010_2 = BR_AM_2010_2.drop('isPartial', 1)

election_year = [years[2]]*len(BR_AM_2010_2.index)
election_round= [rounds[0]]*len(BR_AM_2010_2.index)
region= [regions[1]]*len(BR_AM_2010_2.index)

BR_AM_2010_2['Election Year'] = election_year
BR_AM_2010_2['Election Round'] = election_round
BR_AM_2010_2['Region'] = region

final_4_AM = BR_AM_2010_2.groupby(['Election Year','Election Round','Region']).mean()

final_AM = pd.concat([final_AM,final_4_AM],sort=False)


# Pulling 2010 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[5],
geo=geos[1])

BR_AM_2010_1 = pytrends.interest_over_time()
BR_AM_2010_1 = BR_AM_2010_1.drop('isPartial', 1)

election_year = [years[2]]*len(BR_AM_2010_1.index)
election_round= [rounds[1]]*len(BR_AM_2010_1.index)
region= [regions[1]]*len(BR_AM_2010_1.index)

BR_AM_2010_1['Election Year'] = election_year
BR_AM_2010_1['Election Round'] = election_round
BR_AM_2010_1['Region'] = region

final_5_AM = BR_AM_2010_1.groupby(['Election Year','Election Round','Region']).mean()

final_AM = pd.concat([final_AM,final_5_AM],sort=False)


# Pulling 2006 Round 2 results
# pytrends.build_payload(
# kw_list,
# cat=0,
# timeframe=timeframes[6],
# geo=geos[1])

# BR_AM_2006_2 = pytrends.interest_over_time()
# BR_AM_2006_2 = BR_AM_2006_2.drop('isPartial', 1)

# election_year = [years[3]]*len(BR_AM_2006_2.index)
# election_round= [rounds[0]]*len(BR_AM_2006_2.index)
# region= [regions[1]]*len(BR_AM_2006_2.index)

# BR_AM_2006_2['Election Year'] = election_year
# BR_AM_2006_2['Election Round'] = election_round
# BR_AM_2006_2['Region'] = region

# final_6_AM = BR_AM_2006_2.groupby(['Election Year','Election Round','Region']).mean()

# final_AM = pd.concat([final_AM,final_6_AM],sort=False)


# # Pulling 2006 Round 1 results
# pytrends.build_payload(
# kw_list,
# cat=0,
# timeframe=timeframes[7],
# geo=geos[1])

# BR_AM_2006_1 = pytrends.interest_over_time()
# BR_AM_2006_1 = BR_AM_2006_1.drop('isPartial', 1)

# election_year = [years[3]]*len(BR_AM_2006_1.index)
# election_round= [rounds[1]]*len(BR_AM_2006_1.index)
# region= [regions[1]]*len(BR_AM_2006_2.index)

# BR_AM_2006_1['Election Year'] = election_year
# BR_AM_2006_1['Election Round'] = election_round
# BR_AM_2006_1['Region'] = region

# final_7_AM = BR_AM_2006_1.groupby(['Election Year','Election Round','Region']).mean()

# final_AM = pd.concat([final_AM,final_7_AM],sort=False)
# final_AM

# %%
#Region 3 Compiled

#Pulling 2018 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[0],
geo=geos[2])

BR_BA_2018_2 = pytrends.interest_over_time()
BR_BA_2018_2 = BR_BA_2018_2.drop('isPartial', 1)

election_year = [years[0]]*len(BR_BA_2018_2.index)
election_round= [rounds[0]]*len(BR_BA_2018_2.index)
region= [regions[2]]*len(BR_BA_2018_2.index)

BR_BA_2018_2['Election Year'] = election_year
BR_BA_2018_2['Election Round'] = election_round
BR_BA_2018_2['Region'] = region


final_BA = BR_BA_2018_2.groupby(['Election Year','Election Round','Region']).mean()


# Pulling 2018 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[1],
geo=geos[2])

BR_BA_2018_1 = pytrends.interest_over_time()
BR_BA_2018_1 = BR_BA_2018_1.drop('isPartial', 1)

election_year = [years[0]]*len(BR_BA_2018_1.index)
election_round= [rounds[1]]*len(BR_BA_2018_1.index)
region= [regions[2]]*len(BR_BA_2018_1.index)

BR_BA_2018_1['Election Year'] = election_year
BR_BA_2018_1['Election Round'] = election_round
BR_BA_2018_1['Region'] = region

final_1_BA = BR_BA_2018_1.groupby(['Election Year','Election Round','Region']).mean()

final_BA = pd.concat([final_BA,final_1_BA],sort=False)


# Pulling 2014 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[2],
geo=geos[2])

BR_BA_2014_2 = pytrends.interest_over_time()
BR_BA_2014_2 = BR_BA_2014_2.drop('isPartial', 1)

election_year = [years[1]]*len(BR_BA_2014_2.index)
election_round= [rounds[0]]*len(BR_BA_2014_2.index)
region= [regions[2]]*len(BR_BA_2014_2.index)

BR_BA_2014_2['Election Year'] = election_year
BR_BA_2014_2['Election Round'] = election_round
BR_BA_2014_2['Region'] = region

final_2_BA = BR_BA_2014_2.groupby(['Election Year','Election Round','Region']).mean()

final_BA = pd.concat([final_BA,final_2_BA],sort=False)


# Pulling 2014 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[3],
geo=geos[2])

BR_BA_2014_1 = pytrends.interest_over_time()
BR_BA_2014_1 = BR_BA_2014_1.drop('isPartial', 1)

election_year = [years[1]]*len(BR_BA_2014_1.index)
election_round= [rounds[1]]*len(BR_BA_2014_1.index)
region= [regions[2]]*len(BR_BA_2014_1.index)

BR_BA_2014_1['Election Year'] = election_year
BR_BA_2014_1['Election Round'] = election_round
BR_BA_2014_1['Region'] = region

final_3_BA = BR_BA_2014_1.groupby(['Election Year','Election Round','Region']).mean()

final_BA = pd.concat([final_BA,final_3_BA],sort=False)


# Pulling 2010 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[4],
geo=geos[2])

BR_BA_2010_2 = pytrends.interest_over_time()
BR_BA_2010_2 = BR_BA_2010_2.drop('isPartial', 1)

election_year = [years[2]]*len(BR_BA_2010_2.index)
election_round= [rounds[0]]*len(BR_BA_2010_2.index)
region= [regions[2]]*len(BR_BA_2010_2.index)

BR_BA_2010_2['Election Year'] = election_year
BR_BA_2010_2['Election Round'] = election_round
BR_BA_2010_2['Region'] = region

final_4_BA = BR_BA_2010_2.groupby(['Election Year','Election Round','Region']).mean()

final_BA = pd.concat([final_BA,final_4_BA],sort=False)


# Pulling 2010 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[5],
geo=geos[2])

BR_BA_2010_1 = pytrends.interest_over_time()
BR_BA_2010_1 = BR_BA_2010_1.drop('isPartial', 1)

election_year = [years[2]]*len(BR_BA_2010_1.index)
election_round= [rounds[1]]*len(BR_BA_2010_1.index)
region= [regions[2]]*len(BR_BA_2010_1.index)

BR_BA_2010_1['Election Year'] = election_year
BR_BA_2010_1['Election Round'] = election_round
BR_BA_2010_1['Region'] = region

final_5_BA = BR_BA_2010_1.groupby(['Election Year','Election Round','Region']).mean()

final_BA = pd.concat([final_BA,final_5_BA],sort=False)


# Pulling 2006 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[6],
geo=geos[2])

BR_BA_2006_2 = pytrends.interest_over_time()
BR_BA_2006_2 = BR_BA_2006_2.drop('isPartial', 1)

election_year = [years[3]]*len(BR_BA_2006_2.index)
election_round= [rounds[0]]*len(BR_BA_2006_2.index)
region= [regions[2]]*len(BR_BA_2006_2.index)

BR_BA_2006_2['Election Year'] = election_year
BR_BA_2006_2['Election Round'] = election_round
BR_BA_2006_2['Region'] = region

final_6_BA = BR_BA_2006_2.groupby(['Election Year','Election Round','Region']).mean()

final_BA = pd.concat([final_BA,final_6_BA],sort=False)


# Pulling 2006 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[7],
geo=geos[2])

BR_BA_2006_1 = pytrends.interest_over_time()
BR_BA_2006_1 = BR_BA_2006_1.drop('isPartial', 1)

election_year = [years[3]]*len(BR_BA_2006_1.index)
election_round= [rounds[1]]*len(BR_BA_2006_1.index)
region= [regions[2]]*len(BR_BA_2006_2.index)

BR_BA_2006_1['Election Year'] = election_year
BR_BA_2006_1['Election Round'] = election_round
BR_BA_2006_1['Region'] = region

final_7_BA = BR_BA_2006_1.groupby(['Election Year','Election Round','Region']).mean()

final_BA = pd.concat([final_BA,final_7_BA],sort=False)
final_BA
# Out:
#                                       Economia  Previdência  Bolsa Família  \
# Election Year Election Round Region
# 2018          2              BR-BA   34.600000     8.733333      24.533333
#               1              BR-BA   52.800000     5.866667      21.933333
# 2014          2              BR-BA   46.600000    11.466667       8.066667
#               1              BR-BA   45.333333     5.000000       2.400000
# 2010          2              BR-BA   18.933333     1.800000       2.533333
#               1              BR-BA   27.266667     2.466667       0.000000
# 2006          2              BR-BA   38.400000     3.000000       7.533333
#               1              BR-BA   29.600000     0.000000       0.000000
#
#                                      Desemprego  Plano Governo
# Election Year Election Round Region
# 2018          2              BR-BA    31.800000      41.600000
#               1              BR-BA    37.800000      49.666667
# ...

# %%
#Region 3 Compiled

#Pulling 2018 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[0],
geo=geos[3])

BR_MS_2018_2 = pytrends.interest_over_time()
BR_MS_2018_2 = BR_MS_2018_2.drop('isPartial', 1)

election_year = [years[0]]*len(BR_MS_2018_2.index)
election_round= [rounds[0]]*len(BR_MS_2018_2.index)
region= [regions[3]]*len(BR_MS_2018_2.index)

BR_MS_2018_2['Election Year'] = election_year
BR_MS_2018_2['Election Round'] = election_round
BR_MS_2018_2['Region'] = region


final_MS = BR_MS_2018_2.groupby(['Election Year','Election Round','Region']).mean()


# Pulling 2018 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[1],
geo=geos[3])

BR_MS_2018_1 = pytrends.interest_over_time()
BR_MS_2018_1 = BR_MS_2018_1.drop('isPartial', 1)

election_year = [years[0]]*len(BR_MS_2018_1.index)
election_round= [rounds[1]]*len(BR_MS_2018_1.index)
region= [regions[3]]*len(BR_MS_2018_1.index)

BR_MS_2018_1['Election Year'] = election_year
BR_MS_2018_1['Election Round'] = election_round
BR_MS_2018_1['Region'] = region

final_1_MS = BR_MS_2018_1.groupby(['Election Year','Election Round','Region']).mean()

final_MS = pd.concat([final_MS,final_1_MS],sort=False)


# Pulling 2014 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[2],
geo=geos[3])

BR_MS_2014_2 = pytrends.interest_over_time()
BR_MS_2014_2 = BR_MS_2014_2.drop('isPartial', 1)

election_year = [years[1]]*len(BR_MS_2014_2.index)
election_round= [rounds[0]]*len(BR_MS_2014_2.index)
region= [regions[3]]*len(BR_MS_2014_2.index)

BR_MS_2014_2['Election Year'] = election_year
BR_MS_2014_2['Election Round'] = election_round
BR_MS_2014_2['Region'] = region

final_2_MS = BR_MS_2014_2.groupby(['Election Year','Election Round','Region']).mean()

final_MS = pd.concat([final_MS,final_2_MS],sort=False)


# Pulling 2014 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[3],
geo=geos[3])

BR_MS_2014_1 = pytrends.interest_over_time()
BR_MS_2014_1 = BR_MS_2014_1.drop('isPartial', 1)

election_year = [years[1]]*len(BR_MS_2014_1.index)
election_round= [rounds[1]]*len(BR_MS_2014_1.index)
region= [regions[3]]*len(BR_MS_2014_1.index)

BR_MS_2014_1['Election Year'] = election_year
BR_MS_2014_1['Election Round'] = election_round
BR_MS_2014_1['Region'] = region

final_3_MS = BR_MS_2014_1.groupby(['Election Year','Election Round','Region']).mean()

final_MS = pd.concat([final_MS,final_3_MS],sort=False)


# Pulling 2010 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[4],
geo=geos[3])

BR_MS_2010_2 = pytrends.interest_over_time()
BR_MS_2010_2 = BR_MS_2010_2.drop('isPartial', 1)

election_year = [years[2]]*len(BR_MS_2010_2.index)
election_round= [rounds[0]]*len(BR_MS_2010_2.index)
region= [regions[3]]*len(BR_MS_2010_2.index)

BR_MS_2010_2['Election Year'] = election_year
BR_MS_2010_2['Election Round'] = election_round
BR_MS_2010_2['Region'] = region

final_4_MS = BR_MS_2010_2.groupby(['Election Year','Election Round','Region']).mean()

final_MS = pd.concat([final_MS,final_4_MS],sort=False)


# Pulling 2010 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[5],
geo=geos[3])

BR_MS_2010_1 = pytrends.interest_over_time()
BR_MS_2010_1 = BR_MS_2010_1.drop('isPartial', 1)

election_year = [years[2]]*len(BR_MS_2010_1.index)
election_round= [rounds[1]]*len(BR_MS_2010_1.index)
region= [regions[3]]*len(BR_MS_2010_1.index)

BR_MS_2010_1['Election Year'] = election_year
BR_MS_2010_1['Election Round'] = election_round
BR_MS_2010_1['Region'] = region

final_5_MS = BR_MS_2010_1.groupby(['Election Year','Election Round','Region']).mean()

final_MS = pd.concat([final_MS,final_5_MS],sort=False)


# Pulling 2006 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[6],
geo=geos[3])

BR_MS_2006_2 = pytrends.interest_over_time()
BR_MS_2006_2 = BR_MS_2006_2.drop('isPartial', 1)

election_year = [years[3]]*len(BR_MS_2006_2.index)
election_round= [rounds[0]]*len(BR_MS_2006_2.index)
region= [regions[3]]*len(BR_MS_2006_2.index)

BR_MS_2006_2['Election Year'] = election_year
BR_MS_2006_2['Election Round'] = election_round
BR_MS_2006_2['Region'] = region

final_6_MS = BR_MS_2006_2.groupby(['Election Year','Election Round','Region']).mean()

final_MS = pd.concat([final_MS,final_6_MS],sort=False)


# Pulling 2006 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[7],
geo=geos[3])

BR_MS_2006_1 = pytrends.interest_over_time()
BR_MS_2006_1 = BR_MS_2006_1.drop('isPartial', 1)

election_year = [years[3]]*len(BR_MS_2006_1.index)
election_round= [rounds[1]]*len(BR_MS_2006_1.index)
region= [regions[3]]*len(BR_MS_2006_2.index)

BR_MS_2006_1['Election Year'] = election_year
BR_MS_2006_1['Election Round'] = election_round
BR_MS_2006_1['Region'] = region

final_7_MS = BR_MS_2006_1.groupby(['Election Year','Election Round','Region']).mean()

final_MS = pd.concat([final_MS,final_7_MS],sort=False)
final_MS
# Out:
#                                       Economia  Previdência  Bolsa Família  \
# Election Year Election Round Region
# 2018          2              BR-MS   40.066667     6.666667      17.533333
#               1              BR-MS   27.600000     7.333333       4.333333
# 2014          2              BR-MS   33.333333     4.666667       2.333333
#               1              BR-MS   19.666667     0.000000       0.000000
# 2010          2              BR-MS   18.200000     0.000000       0.000000
#               1              BR-MS   11.866667     0.000000       0.000000
# 2006          2              BR-MS    6.666667     6.533333       0.000000
#               1              BR-MS   12.533333     0.000000       0.000000
#
#                                      Desemprego  Plano Governo
# Election Year Election Round Region
# 2018          2              BR-MS    13.933333      30.333333
#               1              BR-MS     7.133333      24.333333
# ...

# %%
#Region 3 Compiled

#Pulling 2018 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[0],
geo=geos[4])

BR_SP_2018_2 = pytrends.interest_over_time()
BR_SP_2018_2 = BR_SP_2018_2.drop('isPartial', 1)

election_year = [years[0]]*len(BR_SP_2018_2.index)
election_round= [rounds[0]]*len(BR_SP_2018_2.index)
region= [regions[4]]*len(BR_SP_2018_2.index)

BR_SP_2018_2['Election Year'] = election_year
BR_SP_2018_2['Election Round'] = election_round
BR_SP_2018_2['Region'] = region


final_SP = BR_SP_2018_2.groupby(['Election Year','Election Round','Region']).mean()


# Pulling 2018 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[1],
geo=geos[4])

BR_SP_2018_1 = pytrends.interest_over_time()
BR_SP_2018_1 = BR_SP_2018_1.drop('isPartial', 1)

election_year = [years[0]]*len(BR_SP_2018_1.index)
election_round= [rounds[1]]*len(BR_SP_2018_1.index)
region= [regions[4]]*len(BR_SP_2018_1.index)

BR_SP_2018_1['Election Year'] = election_year
BR_SP_2018_1['Election Round'] = election_round
BR_SP_2018_1['Region'] = region

final_1_SP = BR_SP_2018_1.groupby(['Election Year','Election Round','Region']).mean()

final_SP = pd.concat([final_SP,final_1_SP],sort=False)


# Pulling 2014 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[2],
geo=geos[4])

BR_SP_2014_2 = pytrends.interest_over_time()
BR_SP_2014_2 = BR_SP_2014_2.drop('isPartial', 1)

election_year = [years[1]]*len(BR_SP_2014_2.index)
election_round= [rounds[0]]*len(BR_SP_2014_2.index)
region= [regions[4]]*len(BR_SP_2014_2.index)

BR_SP_2014_2['Election Year'] = election_year
BR_SP_2014_2['Election Round'] = election_round
BR_SP_2014_2['Region'] = region

final_2_SP = BR_SP_2014_2.groupby(['Election Year','Election Round','Region']).mean()

final_SP = pd.concat([final_SP,final_2_SP],sort=False)


# Pulling 2014 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[3],
geo=geos[4])

BR_SP_2014_1 = pytrends.interest_over_time()
BR_SP_2014_1 = BR_SP_2014_1.drop('isPartial', 1)

election_year = [years[1]]*len(BR_SP_2014_1.index)
election_round= [rounds[1]]*len(BR_SP_2014_1.index)
region= [regions[4]]*len(BR_SP_2014_1.index)

BR_SP_2014_1['Election Year'] = election_year
BR_SP_2014_1['Election Round'] = election_round
BR_SP_2014_1['Region'] = region

final_3_SP = BR_SP_2014_1.groupby(['Election Year','Election Round','Region']).mean()

final_SP = pd.concat([final_SP,final_3_SP],sort=False)


# Pulling 2010 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[4],
geo=geos[4])

BR_SP_2010_2 = pytrends.interest_over_time()
BR_SP_2010_2 = BR_SP_2010_2.drop('isPartial', 1)

election_year = [years[2]]*len(BR_SP_2010_2.index)
election_round= [rounds[0]]*len(BR_SP_2010_2.index)
region= [regions[4]]*len(BR_SP_2010_2.index)

BR_SP_2010_2['Election Year'] = election_year
BR_SP_2010_2['Election Round'] = election_round
BR_SP_2010_2['Region'] = region

final_4_SP = BR_SP_2010_2.groupby(['Election Year','Election Round','Region']).mean()

final_SP = pd.concat([final_SP,final_4_SP],sort=False)


# Pulling 2010 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[5],
geo=geos[4])

BR_SP_2010_1 = pytrends.interest_over_time()
BR_SP_2010_1 = BR_SP_2010_1.drop('isPartial', 1)

election_year = [years[2]]*len(BR_SP_2010_1.index)
election_round= [rounds[1]]*len(BR_SP_2010_1.index)
region= [regions[4]]*len(BR_SP_2010_1.index)

BR_SP_2010_1['Election Year'] = election_year
BR_SP_2010_1['Election Round'] = election_round
BR_SP_2010_1['Region'] = region

final_5_SP = BR_SP_2010_1.groupby(['Election Year','Election Round','Region']).mean()

final_SP = pd.concat([final_SP,final_5_SP],sort=False)


# Pulling 2006 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[6],
geo=geos[4])

BR_SP_2006_2 = pytrends.interest_over_time()
BR_SP_2006_2 = BR_SP_2006_2.drop('isPartial', 1)

election_year = [years[3]]*len(BR_SP_2006_2.index)
election_round= [rounds[0]]*len(BR_SP_2006_2.index)
region= [regions[4]]*len(BR_SP_2006_2.index)

BR_SP_2006_2['Election Year'] = election_year
BR_SP_2006_2['Election Round'] = election_round
BR_SP_2006_2['Region'] = region

final_6_SP = BR_SP_2006_2.groupby(['Election Year','Election Round','Region']).mean()

final_SP = pd.concat([final_SP,final_6_SP],sort=False)


# Pulling 2006 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[7],
geo=geos[4])

BR_SP_2006_1 = pytrends.interest_over_time()
BR_SP_2006_1 = BR_SP_2006_1.drop('isPartial', 1)

election_year = [years[3]]*len(BR_SP_2006_1.index)
election_round= [rounds[1]]*len(BR_SP_2006_1.index)
region= [regions[4]]*len(BR_SP_2006_2.index)

BR_SP_2006_1['Election Year'] = election_year
BR_SP_2006_1['Election Round'] = election_round
BR_SP_2006_1['Region'] = region

final_7_SP = BR_SP_2006_1.groupby(['Election Year','Election Round','Region']).mean()

final_SP = pd.concat([final_SP,final_7_SP],sort=False)
final_SP
# Out:
#                                       Economia  Previdência  Bolsa Família  \
# Election Year Election Round Region
# 2018          2              BR-SP   51.533333     9.533333      13.066667
#               1              BR-SP   36.600000     7.933333       5.866667
# 2014          2              BR-SP   66.266667     9.066667      12.933333
#               1              BR-SP   70.733333     8.600000       5.333333
# 2010          2              BR-SP   35.133333     9.400000       1.800000
#               1              BR-SP   40.266667     6.600000       0.800000
# 2006          2              BR-SP   42.400000     7.333333       0.000000
#               1              BR-SP   44.266667     8.200000       1.800000
#
#                                      Desemprego  Plano Governo
# Election Year Election Round Region
# 2018          2              BR-SP    56.466667      54.333333
#               1              BR-SP    29.600000      45.000000
# ...

# %%
#Region 3 Compiled

#Pulling 2018 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[0],
geo=geos[5])

BR_RS_2018_2 = pytrends.interest_over_time()
BR_RS_2018_2 = BR_RS_2018_2.drop('isPartial', 1)

election_year = [years[0]]*len(BR_RS_2018_2.index)
election_round= [rounds[0]]*len(BR_RS_2018_2.index)
region= [regions[5]]*len(BR_RS_2018_2.index)

BR_RS_2018_2['Election Year'] = election_year
BR_RS_2018_2['Election Round'] = election_round
BR_RS_2018_2['Region'] = region


final_RS = BR_RS_2018_2.groupby(['Election Year','Election Round','Region']).mean()


# Pulling 2018 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[1],
geo=geos[5])

BR_RS_2018_1 = pytrends.interest_over_time()
BR_RS_2018_1 = BR_RS_2018_1.drop('isPartial', 1)

election_year = [years[0]]*len(BR_RS_2018_1.index)
election_round= [rounds[1]]*len(BR_RS_2018_1.index)
region= [regions[5]]*len(BR_RS_2018_1.index)

BR_RS_2018_1['Election Year'] = election_year
BR_RS_2018_1['Election Round'] = election_round
BR_RS_2018_1['Region'] = region

final_1_RS = BR_RS_2018_1.groupby(['Election Year','Election Round','Region']).mean()

final_RS = pd.concat([final_RS,final_1_RS],sort=False)


# Pulling 2014 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[2],
geo=geos[5])

BR_RS_2014_2 = pytrends.interest_over_time()
BR_RS_2014_2 = BR_RS_2014_2.drop('isPartial', 1)

election_year = [years[1]]*len(BR_RS_2014_2.index)
election_round= [rounds[0]]*len(BR_RS_2014_2.index)
region= [regions[5]]*len(BR_RS_2014_2.index)

BR_RS_2014_2['Election Year'] = election_year
BR_RS_2014_2['Election Round'] = election_round
BR_RS_2014_2['Region'] = region

final_2_RS = BR_RS_2014_2.groupby(['Election Year','Election Round','Region']).mean()

final_RS = pd.concat([final_RS,final_2_RS],sort=False)


# Pulling 2014 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[3],
geo=geos[5])

BR_RS_2014_1 = pytrends.interest_over_time()
BR_RS_2014_1 = BR_RS_2014_1.drop('isPartial', 1)

election_year = [years[1]]*len(BR_RS_2014_1.index)
election_round= [rounds[1]]*len(BR_RS_2014_1.index)
region= [regions[5]]*len(BR_RS_2014_1.index)

BR_RS_2014_1['Election Year'] = election_year
BR_RS_2014_1['Election Round'] = election_round
BR_RS_2014_1['Region'] = region

final_3_RS = BR_RS_2014_1.groupby(['Election Year','Election Round','Region']).mean()

final_RS = pd.concat([final_RS,final_3_RS],sort=False)


# Pulling 2010 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[4],
geo=geos[5])

BR_RS_2010_2 = pytrends.interest_over_time()
BR_RS_2010_2 = BR_RS_2010_2.drop('isPartial', 1)

election_year = [years[2]]*len(BR_RS_2010_2.index)
election_round= [rounds[0]]*len(BR_RS_2010_2.index)
region= [regions[5]]*len(BR_RS_2010_2.index)

BR_RS_2010_2['Election Year'] = election_year
BR_RS_2010_2['Election Round'] = election_round
BR_RS_2010_2['Region'] = region

final_4_RS = BR_RS_2010_2.groupby(['Election Year','Election Round','Region']).mean()

final_RS = pd.concat([final_RS,final_4_RS],sort=False)


# Pulling 2010 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[5],
geo=geos[5])

BR_RS_2010_1 = pytrends.interest_over_time()
BR_RS_2010_1 = BR_RS_2010_1.drop('isPartial', 1)

election_year = [years[2]]*len(BR_RS_2010_1.index)
election_round= [rounds[1]]*len(BR_RS_2010_1.index)
region= [regions[5]]*len(BR_RS_2010_1.index)

BR_RS_2010_1['Election Year'] = election_year
BR_RS_2010_1['Election Round'] = election_round
BR_RS_2010_1['Region'] = region

final_5_RS = BR_RS_2010_1.groupby(['Election Year','Election Round','Region']).mean()

final_RS = pd.concat([final_RS,final_5_RS],sort=False)


# Pulling 2006 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[6],
geo=geos[5])

BR_RS_2006_2 = pytrends.interest_over_time()
BR_RS_2006_2 = BR_RS_2006_2.drop('isPartial', 1)

election_year = [years[3]]*len(BR_RS_2006_2.index)
election_round= [rounds[0]]*len(BR_RS_2006_2.index)
region= [regions[5]]*len(BR_RS_2006_2.index)

BR_RS_2006_2['Election Year'] = election_year
BR_RS_2006_2['Election Round'] = election_round
BR_RS_2006_2['Region'] = region

final_6_RS = BR_RS_2006_2.groupby(['Election Year','Election Round','Region']).mean()

final_RS = pd.concat([final_RS,final_6_RS],sort=False)


# Pulling 2006 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[7],
geo=geos[5])

BR_RS_2006_1 = pytrends.interest_over_time()
BR_RS_2006_1 = BR_RS_2006_1.drop('isPartial', 1)

election_year = [years[3]]*len(BR_RS_2006_1.index)
election_round= [rounds[1]]*len(BR_RS_2006_1.index)
region= [regions[5]]*len(BR_RS_2006_2.index)

BR_RS_2006_1['Election Year'] = election_year
BR_RS_2006_1['Election Round'] = election_round
BR_RS_2006_1['Region'] = region

final_7_RS = BR_RS_2006_1.groupby(['Election Year','Election Round','Region']).mean()

final_RS = pd.concat([final_RS,final_7_RS],sort=False)
final_RS
# Out:
#                                       Economia  Previdência  Bolsa Família  \
# Election Year Election Round Region
# 2018          2              BR-RS   58.266667     9.266667      12.266667
#               1              BR-RS   53.666667     9.200000       4.933333
# 2014          2              BR-RS   52.666667    10.666667       3.666667
#               1              BR-RS   33.466667     4.800000       2.600000
# 2010          2              BR-RS   37.200000     1.400000       0.000000
#               1              BR-RS   30.200000     4.133333       2.066667
# 2006          2              BR-RS   28.066667     9.266667       2.266667
#               1              BR-RS   27.600000     3.200000       0.000000
#
#                                      Desemprego  Plano Governo
# Election Year Election Round Region
# 2018          2              BR-RS    36.733333      44.400000
#               1              BR-RS    40.933333      52.733333
# ...

# %%
final = pd.concat([final,final_AM],sort=False)
final = pd.concat([final,final_BA],sort=False)
final = pd.concat([final,final_MS],sort=False)
final = pd.concat([final,final_SP],sort=False)
final = pd.concat([final,final_RS],sort=False)

# %%
final = final.astype(int)

# %%
final_try = final.reset_index()
final_try
# Out:
#    Election Year Election Round Region  Economia  Previdência  Bolsa Família  \
# 0           2018              2     BR        73           12             23
# 1           2018              1     BR        48            8             10
# 2           2014              2     BR        71           11             12
# 3           2014              1     BR        66           10              6
# 4           2010              2     BR        59            7              2
# 5           2010              1     BR        64            5              0
# 6           2006              2     BR        55            7              0
# 7           2006              1     BR        56           11              1
# 8           2018              2  BR-AM        36            8             19
# 9           2018              1  BR-AM        40            6              4
# 10          2014              2  BR-AM        28            2             10
# ...

# %%
#graph 
(
    ggplot(data = final_try, mapping = aes(x="Election Year", y="Economia")) +
    geom_col() +
    theme(axis_text_x  = element_text(angle = 90, hjust = 1))+
    ggtitle("Election Year x Economia")
)
# Out:
# <ggplot: (8783229766660)>

# %%
final_try.plot(x=["Economia","Previdência", "Bolsa Família", "Desemprego", "Plano Governo"], y=["Election Years"], kind="bar")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/yb/_vwl36s15rv49b1lf71677cr0000gn/T/ipykernel_90275/55220831.py in <module>
# ----> 1 final_try.plot(x=["Economia","Previdência", "Bolsa Família", "Desemprego", "Plano Governo"], y=["Election Years"], kind="bar")
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     936                     x = data_cols[x]
#     937                 elif not isinstance(data[x], ABCSeries):
# --> 938                     raise ValueError("x must be a label or position")
#     939                 data = data.set_index(x)
#     940             if y is not None:
#
# ValueError: x must be a label or position

# %%
(
    ggplot(final_try, aes(x = "Election Year", y = "Economia"))+
      geom_line()
)
# Out:
# <ggplot: (8783174778498)>

# %%
ggplot(final_try, aes(x=Election Year)) + 
  geom_line(aes(y = Economia), color = "darkred") + 
  geom_line(aes(y = Previdência), color="steelblue", linetype="twodash")
# Out:
#   File "/var/folders/yb/_vwl36s15rv49b1lf71677cr0000gn/T/ipykernel_90275/1802087283.py", line 1
#     ggplot(final_try, aes(x=Election Year)) +
#                                      ^
# SyntaxError: invalid syntax

# %%
fig, ax = plt.subplots(figsize=(12, 8))
x = np.arange(len(final_try.job.unique()))
bar_width = 0.4
b1 = ax.bar(x, df.loc[df['sex'] == 'men', 'count'],
            width=bar_width)
b2 = ax.bar(x + bar_width, df.loc[df['sex'] == 'women', 'count'],
            width=bar_width)

# Fix the x-axes.
ax.set_xticks(x + bar_width / 2)
ax.set_xticklabels(df.job.unique())

# %%
# final_try.plot(x=["Election Year"], y=["Economia"], kind="bar")
