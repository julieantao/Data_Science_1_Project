# %%
#import packages
from pytrends.request import TrendReq
import csv
import time
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
#Connecting to Google (WORKS)
pytrends = TrendReq(hl='en-US', tz=360)

# %%
#Building Payload
kw_list = ["Economia", "Previdência", "Bolsa Família", "Desemprego", "Plano Governo"]
timeframes = ['2018-10-14 2018-10-28', '2018-9-23 2018-10-7', '2014-10-12 2014-10-26', '2014-9-21 2014-10-5', '2010-10-17 2010-10-31', '2010-9-19 2010-10-3', '2006-10-15 2006-10-29', '2006-9-17 2006-10-1']
#segmented for national and most populous states in each region
geos = ["BR","BR-AM", "BR-BA", "BR-MS", "BR-SP", "BR-RS"]

# %%
#definitions for columns
election = ["2018-2", "2018-1", "2014-2","2014-1", "2010-2","2010-1", "2006-2", "2006-1"]
regions = ["BR","BR-AM", "BR-BA", "BR-MS", "BR-SP", "BR-RS"]

# %%
#Pulling 2018 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[0],
geo=geos[0])

BR_2018_2 = pytrends.interest_over_time()
BR_2018_2 = BR_2018_2.drop('isPartial', 1)

election_round = [election[0]]*len(BR_2018_2.index)
region= [regions[0]]*len(BR_2018_2.index)
BR_2018_2['round'] = election_round
BR_2018_2['region'] = region

final_1 = BR_2018_2.groupby(["round","region"]).mean()
final_1
# Out:
#                 Economia  Previdência  Bolsa Família  Desemprego  \
# round  region
# 2018-2 BR      55.533333         10.6      18.066667        43.6
#
#                Plano Governo
# round  region
# 2018-2 BR          52.333333

# %%
#Pulling 2018 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[1],
geo=geos[0])

BR_2018_1 = pytrends.interest_over_time()
BR_2018_1 = BR_2018_1.drop('isPartial', 1)

election_round = [election[1]]*len(BR_2018_1.index)
region= [regions[0]]*len(BR_2018_1.index)
BR_2018_1['round'] = election_round
BR_2018_1['region'] = region

final_2 = BR_2018_1.groupby(["round","region"]).mean()
final_2

final = pd.concat([final_1,final_2],sort=False)
final
# Out:
#                 Economia  Previdência  Bolsa Família  Desemprego  \
# round  region
# 2018-2 BR      55.533333    10.600000      18.066667   43.600000
# 2018-1 BR      51.733333     9.333333      10.266667   35.266667
#
#                Plano Governo
# round  region
# 2018-2 BR          52.333333
# 2018-1 BR          47.733333

# %%
#Pulling 2014 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[2],
geo=geos[0])

BR_2014_2 = pytrends.interest_over_time()
BR_2014_2 = BR_2014_2.drop('isPartial', 1)

election_round = [election[2]]*len(BR_2014_2.index)
region= [regions[0]]*len(BR_2014_2.index)
BR_2014_2['round'] = election_round
BR_2014_2['region'] = region

final_3 = BR_2014_2.groupby(["round","region"]).mean()
final_3

final = pd.concat([final,final_3],sort=False)
final
# Out:
#                 Economia  Previdência  Bolsa Família  Desemprego  \
# round  region
# 2018-2 BR      55.533333    10.600000      18.066667   43.600000
# 2018-1 BR      51.733333     9.333333      10.266667   35.266667
# 2014-2 BR      75.200000    11.466667      13.000000   60.933333
#
#                Plano Governo
# round  region
# 2018-2 BR          52.333333
# 2018-1 BR          47.733333
# 2014-2 BR          10.666667

# %%
#Pulling 2014 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[3],
geo=geos[0])

BR_2014_1 = pytrends.interest_over_time()
BR_2014_1 = BR_2014_1.drop('isPartial', 1)

election_round = [election[3]]*len(BR_2014_1.index)
region= [regions[0]]*len(BR_2014_1.index)
BR_2014_1['round'] = election_round
BR_2014_1['region'] = region

final_4 = BR_2014_1.groupby(["round","region"]).mean()
final_4

final = pd.concat([final,final_4],sort=False)
final
# Out:
#                 Economia  Previdência  Bolsa Família  Desemprego  \
# round  region
# 2018-2 BR      55.533333    10.600000      18.066667   43.600000
# 2018-1 BR      51.733333     9.333333      10.266667   35.266667
# 2014-2 BR      75.200000    11.466667      13.000000   60.933333
# 2014-1 BR      70.000000    11.333333       6.533333   50.733333
#
#                Plano Governo
# round  region
# 2018-2 BR          52.333333
# 2018-1 BR          47.733333
# 2014-2 BR          10.666667
# 2014-1 BR          15.866667

# %%
#Pulling 2010 Round 2 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[4],
geo=geos[0])

BR_2010_2 = pytrends.interest_over_time()
BR_2010_2 = BR_2010_2.drop('isPartial', 1)

election_round = [election[4]]*len(BR_2010_2.index)
region= [regions[0]]*len(BR_2010_2.index)
BR_2010_2['round'] = election_round
BR_2010_2['region'] = region

final_5 = BR_2010_2.groupby(["round","region"]).mean()
final_5

final = pd.concat([final,final_5],sort=False)
final
# Out:
#                 Economia  Previdência  Bolsa Família  Desemprego  \
# round  region
# 2018-2 BR      55.533333    10.600000      18.066667   43.600000
# 2018-1 BR      51.733333     9.333333      10.266667   35.266667
# 2014-2 BR      75.200000    11.466667      13.000000   60.933333
# 2014-1 BR      70.000000    11.333333       6.533333   50.733333
# 2010-2 BR      68.066667     9.200000       1.800000   30.000000
#
#                Plano Governo
# round  region
# 2018-2 BR          52.333333
# 2018-1 BR          47.733333
# 2014-2 BR          10.666667
# 2014-1 BR          15.866667
# 2010-2 BR           1.866667

# %%
#Pulling 2010 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[5],
geo=geos[0])

BR_2010_1 = pytrends.interest_over_time()
BR_2010_1 = BR_2010_1.drop('isPartial', 1)

election_round = [election[5]]*len(BR_2010_1.index)
region= [regions[0]]*len(BR_2010_1.index)
BR_2010_1['round'] = election_round
BR_2010_1['region'] = region

final_6 = BR_2010_1.groupby(["round","region"]).mean()
final_6

final = pd.concat([final,final_6],sort=False)
final
# Out:
#                 Economia  Previdência  Bolsa Família  Desemprego  \
# round  region
# 2018-2 BR      55.533333    10.600000      18.066667   43.600000
# 2018-1 BR      51.733333     9.333333      10.266667   35.266667
# 2014-2 BR      75.200000    11.466667      13.000000   60.933333
# 2014-1 BR      70.000000    11.333333       6.533333   50.733333
# 2010-2 BR      68.066667     9.200000       1.800000   30.000000
# 2010-1 BR      66.933333     7.066667       1.000000   26.866667
#
#                Plano Governo
# round  region
# 2018-2 BR          52.333333
# 2018-1 BR          47.733333
# 2014-2 BR          10.666667
# 2014-1 BR          15.866667
# 2010-2 BR           1.866667
# 2010-1 BR           4.733333
