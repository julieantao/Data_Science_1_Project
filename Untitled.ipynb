# %%
#import packages
from pytrends.request import TrendReq
import csv
import time
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
#Connecting to Google (WORKS)
pytrends = TrendReq(hl='en-US', tz=360)

# %%
#Building Payload
kw_list = ["Economia", "Previdência", "Bolsa Família", "Desemprego", "Plano Governo"]
timeframes = ['2018-10-14 2018-10-28', '2018-9-23 2018-10-7', '2014-10-12 2014-10-26', '2014-9-21 2014-10-5', '2010-10-17 2010-10-31', '2010-9-19 2010-10-3', '2006-10-15 2006-10-29', '2006-9-17 2006-10-1']
#segmented for national and most populous states in each region
geos = ["BR","BR-AM", "BR-BA", "BR-MS", "BR-SP", "BR-RS"]

# %%
#definitions for columns
years = ["2018", "2014", "2010","2006",]
rounds = ["2","1"]
regions = ["BR","BR-AM", "BR-BA", "BR-MS", "BR-SP", "BR-RS"]

# %%
# Pulling 2006 Round 1 results
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[7],
geo=geos[1])

# %%
BR_AM_2006_1 = pytrends.interest_over_time()

# %%
BR_AM_2006_1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pytrends.build_payload(
kw_list,
cat=0,
timeframe=timeframes[5],
geo=geos[1])

BR_AM_2010_1 = pytrends.interest_over_time()

# %%
BR_AM_2010_1
# Out:
#             Economia  Previdência  Bolsa Família  Desemprego  Plano Governo  \
# date
# 2010-09-19         0            0              0           0              0
# 2010-09-20         0            0              0           0              0
# 2010-09-21         0            0              0           0              0
# 2010-09-22        83            0              0          83              0
# 2010-09-23         0            0              0           0              0
# 2010-09-24         0            0              0           0              0
# 2010-09-25         0            0              0           0              0
# 2010-09-26         0            0              0           0              0
# 2010-09-27         0            0              0           0              0
# 2010-09-28         0            0              0           0              0
# 2010-09-29         0            0              0           0              0
# 2010-09-30       100            0              0           0              0
# 2010-10-01         0            0              0           0              0
# 2010-10-02         0            0              0           0              0
# 2010-10-03         0            0              0           0              0
#
#             isPartial
# date
# 2010-09-19      False
# 2010-09-20      False
# 2010-09-21      False
# 2010-09-22      False
# 2010-09-23      False
# 2010-09-24      False
# 2010-09-25      False
# 2010-09-26      False
# 2010-09-27      False
# 2010-09-28      False
# 2010-09-29      False
# 2010-09-30      False
# 2010-10-01      False
# 2010-10-02      False
# 2010-10-03      False
